# %% [markdown]
# ### Introduction
# The Horse Colic Dataset is a collection of medical records for horses suffering from colic, a common equine emergency. The dataset aims to predict the outcome (survival or non-survival) of horses based on their medical conditions, treatment, and other factors. With 28 attributes and 368 instances, this dataset provides a comprehensive understanding of equine colic and its management.
#
# ### Dataset Information
# The Horse Colic Dataset contains 368 instances, each representing a horse's medical record. The dataset includes 28 attributes, which can be categorized into:
# - Demographic information (age, hospital number)
# - Clinical measurements (rectal temperature, pulse, respiratory rate, etc.)
# - Subjective assessments (pain level, mucous membranes, capillary refill time, etc.)
# - Treatment and diagnostic information (surgery, nasogastric tube, abdominocentesis, etc.)
# - Outcome (lived, died, euthanized)
#
# The dataset also includes information on the type of lesion, its location, and whether surgery was performed. Missing values (NA's) are present in the data, requiring appropriate handling for analysis.
#
# ### Data Dictionary
#
# | **Variable Name**        | **Description**                                                                                                   | **Type**  | **Possible Values**                                                                                                     |
# |--------------------------|-------------------------------------------------------------------------------------------------------------------|-----------|--------------------------------------------------------------------------------------------------------------------------|
# | `surgery`                | Indicates whether surgery was performed.                                                                          | Categorical | 1 = Yes, it had surgery<br>2 = It was treated without surgery                                                             |
# | `Age`                    | Age category of the horse.                                                                                        | Categorical | 1 = Adult horse<br>2 = Young (< 6 months)                                                                                |
# | `Hospital_Number`        | Numeric ID assigned to the horse (not unique if treated multiple times).                                          | Numeric   | Case number assigned to the horse.                                                                                       |
# | `rectal_temperature`     | Rectal temperature in degrees Celsius.                                                                            | Numeric   | Continuous (e.g., 37.8).                                                                                                 |
# | `pulse`                  | Heart rate in beats per minute.                                                                                   | Numeric   | Continuous (e.g., 30-40).                                                                                                |
# | `respiratory_rate`       | Respiratory rate in breaths per minute.                                                                           | Numeric   | Continuous (e.g., 8-10).                                                                                                 |
# | `temperature_of_extremities` | Subjective indication of peripheral circulation based on extremity temperature.                                 | Categorical | 1 = Normal<br>2 = Warm<br>3 = Cool<br>4 = Cold                                                                           |
# | `peripheral_pulse`       | Subjective assessment of peripheral pulse strength.                                                               | Categorical | 1 = Normal<br>2 = Increased<br>3 = Reduced<br>4 = Absent                                                                 |
# | `mucous_membranes`       | Subjective assessment of mucous membrane color.                                                                   | Categorical | 1 = Normal pink<br>2 = Bright pink<br>3 = Pale pink<br>4 = Pale cyanotic<br>5 = Bright red / Injected<br>6 = Dark cyanotic|
# | `capillary_refill_time`  | Time taken for capillary refill.                                                                                  | Categorical | 1 = < 3 seconds<br>2 = >= 3 seconds                                                                                       |
# | `pain`                   | Subjective judgment of the horse's pain level.                                                                     | Categorical | 1 = Alert, no pain<br>2 = Depressed<br>3 = Intermittent mild pain<br>4 = Intermittent severe pain<br>5 = Continuous severe pain |
# | `peristalsis`            | Gut activity level.                                                                                               | Categorical | 1 = Hypermotile<br>2 = Normal<br>3 = Hypomotile<br>4 = Absent                                                            |
# | `abdominal_distension`   | Degree of abdominal distension.                                                                                   | Categorical | 1 = None<br>2 = Slight<br>3 = Moderate<br>4 = Severe                                                                     |
# | `nasogastric_tube`       | Presence of gas coming out of the nasogastric tube.                                                               | Categorical | 1 = None<br>2 = Slight<br>3 = Significant                                                                                |
# | `nasogastric_reflux`     | Amount of reflux.                                                                                                 | Categorical | 1 = None<br>2 = > 1 liter<br>3 = < 1 liter                                                                               |
# | `nasogastric_reflux_PH`  | pH level of the nasogastric reflux.                                                                               | Numeric   | Continuous (e.g., 3-4).                                                                                                  |
# | `rectal_examination_feces` | Results of the rectal examination regarding feces.                                                              | Categorical | 1 = Normal<br>2 = Increased<br>3 = Decreased<br>4 = Absent                                                               |
# | `abdomen`                | Condition of the abdomen based on examination.                                                                    | Categorical | 1 = Normal<br>2 = Other<br>3 = Firm feces in the large intestine<br>4 = Distended small intestine<br>5 = Distended large intestine |
# | `packed_cell_volume`     | Number of red cells by volume in the blood.                                                                       | Numeric   | Continuous (normal range is 30-50).                                                                                      |
# | `total_protein`          | Total protein in g/dL.                                                                                            | Numeric   | Continuous (normal range is 6-7.5 g/dL).                                                                                 |
# | `abdominocentesis_appearance` | Appearance of fluid obtained from the abdominal cavity.                                                     | Categorical | 1 = Clear<br>2 = Cloudy<br>3 = Serosanguinous                                                                            |
# | `abdomcentesis_total_protein` | Total protein in the fluid obtained from abdominocentesis in g/dL.                                           | Numeric   | Continuous.                                                                                                              |
# | `outcome`                | The final outcome for the horse.                                                                                  | Categorical | 1 = Lived<br>2 = Died<br>3 = Was euthanized                                                                              |
# | `surgical_lesion`        | Whether the problem was determined to be surgical.                                                                | Categorical | 1 = Yes<br>2 = No                                                                                                        |
# | `lesion_type_site`       | Site of the lesion.                                                                                               | Categorical | 1 = Gastric<br>2 = Small intestine<br>3 = Large colon<br>4 = Large colon and cecum<br>5 = Cecum<br>6 = Transverse colon<br>7 = Rectum/descending colon<br>8 = Uterus<br>9 = Bladder<br>11 = All intestinal sites<br>00 = None |
# | `lesion_type_type`       | Type of lesion.                                                                                                   | Categorical | 1 = Simple<br>2 = Strangulation<br>3 = Inflammation<br>4 = Other                                                          |
# | `lesion_type_subtype`    | Subtype of lesion.                                                                                                | Categorical | 1 = Mechanical<br>2 = Paralytic<br>0 = N/A                                                                               |
# | `lesion_type_specific_code` | Specific code for the lesion.                                                                                 | Categorical | 1 = Obturations<br>2 = Intrinsic<br>3 = Extrinsic<br>4 = Adynamic<br>5 = Volvulus/torsion<br>6 = Intussuption<br>7 = Thromboembolic<br>8 = Hernia<br>9 = Lipoma/splenic incarceration<br>10 = Displacement<br>0 = N/A |
# | `cp_data`                | Indicates if pathology data is present.                                                                           | Categorical | 1 = Yes<br>2 = No                                                                                                        |
#
# ### Acknowledgements:
# This dataset was originally published by the UCI Machine Learning Database: http://archive.ics.uci.edu/ml/datasets/Horse+Colic

# %%
# !pip3 install -r requirements.txt --quiet

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd 
pd.set_option('display.max_columns', None)
import seaborn as sns
from scipy.stats import anderson
import matplotlib.pyplot as plt
import sqlite3
# %matplotlib inline
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = (22,5)
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# %%
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler, RobustScaler, label_binarize
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

#Models
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

#Model Performance Evaluators
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, accuracy_score

# %%
URL = 'https://raw.githubusercontent.com/dakshbhatnagar/Datasets/refs/heads/main/horse_survival/train.csv'
df =  pd.read_csv(URL)
df.drop(columns=['id'], inplace=True)
df.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0     yes  adult           530001         38.1  132.0              24.0
# 1     yes  adult           533836         37.5   88.0              12.0
# 2     yes  adult           529812         38.3  120.0              28.0
# 3     yes  adult          5262541         37.1   72.0              30.0
# 4      no  adult          5299629         38.0   52.0              48.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced   dark_cyanotic            more_3_sec
# 1                cool           normal   pale_cyanotic            more_3_sec
# 2                cool          reduced       pale_pink            less_3_sec
# 3                cold          reduced       pale_pink            more_3_sec
# 4              normal           normal     normal_pink            less_3_sec
#
#            pain peristalsis abdominal_distention nasogastric_tube  \
# ...

# %%
#Summary Stats of the dataset
df.describe().T
# Out:
#                         count           mean           std       min  \
# hospital_number        1235.0  954500.401619  1.356403e+06  521399.0
# rectal_temp            1235.0      38.202186  7.886678e-01      35.4
# pulse                  1235.0      79.574089  2.910864e+01      30.0
# respiratory_rate       1235.0      30.054251  1.645207e+01       8.0
# nasogastric_reflux_ph  1235.0       4.382591  1.937357e+00       1.0
# packed_cell_volume     1235.0      49.602429  1.053580e+01      23.0
# total_protein          1235.0      21.388016  2.667645e+01       3.5
# abdomo_protein         1235.0       3.290931  1.589195e+00       0.1
# lesion_1               1235.0    3832.496356  5.436734e+03       0.0
# lesion_2               1235.0      14.612146  1.937057e+02       0.0
# lesion_3               1235.0       3.577328  8.885895e+01       0.0
#
#                             25%       50%       75%        max
# hospital_number        528800.0  529777.0  534145.0  5305129.0
# ...

# %% [markdown]
# Null Value Percentage Dataframe telling us abdomen has most null values. Since we will be doing Machine Learning, we will have to deal with this later on.

# %%
null_df = pd.DataFrame(round(df.isnull().sum()/len(df)*100,2)).reset_index()\
            .rename(columns={'index': 'Column', 0:'Null_Pct'})\
            .sort_values(by='Null_Pct', ascending=False)\
            .reset_index(drop=True).query('Null_Pct>0')
null_df
# Out:
#                    Column  Null_Pct
# 0                 abdomen     17.25
# 1       rectal_exam_feces     15.38
# 2        nasogastric_tube      6.48
# 3        peripheral_pulse      4.86
# 4       abdomo_appearance      3.89
# 5                    pain      3.56
# 6     temp_of_extremities      3.16
# 7    abdominal_distention      1.86
# 8      nasogastric_reflux      1.70
# 9         mucous_membrane      1.70
# 10            peristalsis      1.62
# 11  capillary_refill_time      0.49

# %%
conn = sqlite3.connect('horse_disease.db')
df.to_sql('data', conn, if_exists='replace', index=False)
# Out:
# 1235

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **Question:** - How many horses are there?

# %%
horses = len(df)
print(f"There are {horses:,} horses in the dataset.")
# Out:
# There are 1,235 horses in the dataset.

# %% [markdown]
# **Question**: - Show a distribution of the surgeries

# %%
query = '''
select surgery, round(count(surgery)/1235.0*100,2) as Percent 
        from data 
group by 1
'''
temp = pd.read_sql(query, conn)
temp
# Out:
#   surgery  Percent
# 0      no    28.18
# 1     yes    71.82

# %% [markdown]
# **INSIGHT**
#
# - 71% have had surgery while 28% have not had surgery

# %% [markdown]
# **QUESTION** - Show the outcome percentage distribution

# %%
query = '''
select outcome, round(count(outcome)/1235.0*100,2) as Percent 
        from data 
group by 1
order by 2 desc
'''
colors = ['#F05A7E', '#125B9A', '#0B8494']
temp = pd.read_sql(query, conn)
plt.bar(x=temp['outcome'], height=temp['Percent'], color=colors)
plt.title('Outcome Percentage Distribution')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# **INISGHT**
#
# - 46.5% horses have lived however 33.2% have died.
# - Euthanized means to end an animal's life humanely, typically to prevent further suffering or pain. It is a deliberate act to end an animal's life, usually performed by a veterinarian.

# %% [markdown]
# **Show the age distribution**

# %%
query = '''
select age, round(count(age)/1235.0*100,2) as Percent 
        from data 
group by 1
'''
colors = ['#E85C0D', '#FABC3F']
temp = pd.read_sql(query, conn)
plt.bar(x=temp['age'], height=temp['Percent'], color=colors)
plt.title('Age Percentage Distribution')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# **INSIGHT**
#
# 1. Adults are 93% while Youung (less than 6 months) horses are only 6%

# %%
cat_cols = df.select_dtypes('object').columns.to_list()
num_cols = df.select_dtypes('float').columns.to_list() + df.select_dtypes('int').columns.to_list()

# %%
query = '''
select pain, round(count(pain)/1235.0*100,2) as Percent 
        from data where pain is not null
group by 1
order by 2 desc
'''
pain = pd.read_sql(query, conn)
num_bars = len(pain)

# Generate colors using the Oranges colormap, with darker shades first
colors = plt.cm.Oranges(np.linspace(1, 0.4, num_bars))

# Plotting the bar chart with the gradient colors
plt.bar(x=pain['pain'], height=pain['Percent'], color=colors)
plt.title('Pain Percentage Distribution')
plt.ylabel('Percentage')
plt.show()

# %%
df.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0     yes  adult           530001         38.1  132.0              24.0
# 1     yes  adult           533836         37.5   88.0              12.0
# 2     yes  adult           529812         38.3  120.0              28.0
# 3     yes  adult          5262541         37.1   72.0              30.0
# 4      no  adult          5299629         38.0   52.0              48.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced   dark_cyanotic            more_3_sec
# 1                cool           normal   pale_cyanotic            more_3_sec
# 2                cool          reduced       pale_pink            less_3_sec
# 3                cold          reduced       pale_pink            more_3_sec
# 4              normal           normal     normal_pink            less_3_sec
#
#            pain peristalsis abdominal_distention nasogastric_tube  \
# ...

# %% [markdown]
# **Find out how many horses have surgical lesions?**

# %%
query = '''
select abdomen, round(count(abdomen)/1235.0*100,2) as Percent 
        from data where abdomen is not null
group by 1
order by 2 desc
'''
colors = ['#E85C0D', '#C7253E']
abdomen = pd.read_sql(query, conn)
num_bars = len(abdomen)
# Generate colors using the Blues colormap, with darker shades first
colors = plt.cm.Blues(np.linspace(1, 0.4, num_bars))
plt.bar(x=abdomen['abdomen'], height=abdomen['Percent'], color=colors)
plt.title('Abdomen Percentage Distribution')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# **INSIGHT**
#
# - Distended small and distended large intestine indicate a surgical lesion. 68% of the horses have the surgical lesions.
# - A surgical lesion is a condition or abnormality in an animal (e.g., a horse) that requires surgical intervention to address. It generally indicates a serious issue that cannot be resolved with non-surgical treatments alone.

# %% [markdown]
# **Was surgery able to save these horses lives who had distended small and large intenstine?**

# %%
condition1 =  df['abdomen'].isin(['distend_large','distend_small'])
condition2 = df['surgery']=='yes'

temp1 = df[(condition1) & (condition2)]
pivot = temp1.pivot_table(index='outcome', columns='abdomen', aggfunc='size', fill_value=0)\
                    .reset_index().rename_axis(columns=None)
pivot['Total'] = pivot.set_index('outcome').sum(axis=1).values.tolist()
pivot['distend_large'] = round(pivot['distend_large']/pivot['Total']*100,2)
pivot['distend_small'] = round(pivot['distend_small']/pivot['Total']*100,2)
pivot
# Out:
#       outcome  distend_large  distend_small  Total
# 0        died          38.10          61.90    252
# 1  euthanized          50.38          49.62    131
# 2       lived          38.23          61.77    293

# %% [markdown]
# **INSIGHT**
#
# - If the horse has had distended small intestine and went through a surgery, in 61% of the cases he died and in 49% cases he was euthanized.
# - There is also a 61% chance of horse living if he had a distended small intestine and went through with the surgery.

# %% [markdown]
# **Is surgery a sure shot way of saving the horse or not?**

# %%
pivot = df.pivot_table(index='surgery', columns='outcome', aggfunc='size', fill_value=0).reset_index().rename_axis(columns=None)
pivot['Total'] =  pivot.set_index('surgery').sum(axis=1).values.tolist()
pivot['died'] = round(pivot['died'] / pivot['Total'] * 100,2).values.tolist()
pivot['euthanized'] = round(pivot['euthanized'] / pivot['Total'] * 100,2).values.tolist()
pivot['lived'] = round(pivot['lived'] / pivot['Total'] * 100,2).values.tolist()
pivot['dead'] = pivot['died'] + pivot['euthanized'].values.tolist()
pivot = pivot[['surgery','dead', 'lived', 'Total']]
pivot
# Out:
#   surgery   dead  lived  Total
# 0      no  43.96  56.03    348
# 1     yes  57.27  42.73    887

# %%
pivot.set_index('surgery')[['dead', 'lived']].plot(kind='bar')
plt.title('Surgery and Outcome Chart')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **INSIGHT**
#
# -  57% of the horses who went through the surgery ended up not living any more meaning 19 out of 33 horses.
# - 56% of the horses who were not put under the needle lived meaning 14 out of 25 horses.
# - Surgery cannot confirm if the horse will live.

# %% [markdown]
# **Is Surgery Helpful in cases where the horse has had a surgical lesion?**

# %%
query = '''
select outcome, 
        round(sum(case when outcome='lived' then 1 else 0 end)*1.0/790*100,2) as Percent 
from data 
where surgical_lesion = 'yes' and surgery = 'yes' and outcome='lived'
group by 1

union

select 'died' as outcome, 
        round(sum(case when outcome!='lived' then 1 else 0 end)*1.0/790*100,2) as Percent 
from data 
where surgical_lesion = 'yes' and surgery = 'yes' and  outcome!='lived'

'''
colors = ['#C7253E', '#0D7C66']
lesions = pd.read_sql(query, conn)
plt.bar(x=lesions.outcome, height=lesions['Percent'], color=colors)
plt.title('Surgery helps with Surgical Lesions?')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **INSIGHT**
#
# - In 56% of the cases where the horse had a surgical lesion and was put through a surgery, the horse died
# - On the flip side, 43% of the cases where the horse had a surgical lesion and was put through a surgery, the horse lived

# %% [markdown]
# **How does the color of mucous membrane impact the outcome?**

# %%
data = (df[df['mucous_membrane'].isin(['pale_cyanotic', 'bright_red', 'dark_cyanotic'])]['outcome']
        .value_counts().to_frame()/582*100).round(2).rename(columns={'count': 'Percent'})

# Ensure colors match the number of unique outcomes
colors = ['#921A40', '#C75B7A', '#D9ABAB']  # Adjust colors to match unique outcomes

# Plotting
data.plot(kind='bar', color=colors)
plt.bar(x=data.index, height=data['Percent'], color=colors)
plt.title('Mucous Membrane and Outcome Chart (4 to 6)')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.show()

# %%
data = (df[df['mucous_membrane'].isin(['pale_pink', 'bright_pink', 'normal_pink'])]['outcome']
        .value_counts().to_frame()/632*100).round(2).rename(columns={'count': 'Percent'})

# Ensure colors match the number of unique outcomes
colors = ['#6A9C89', '#C1D8C3', '#FFF5E4']  # Adjust colors to match unique outcomes

# Plotting
data.plot(kind='bar', color=colors)

plt.bar(x=data.index, height=data['Percent'], color=colors)
plt.title('Mucous Membrane and Outcome Chart (1 to 3)')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **Insight**
#
# - If the horse's mucous membrane color in any of this 'pale_cyanotic', 'bright_red', 'dark_cyanotic', he is more likely to die
# - If the horse's mucous membrane color in any of this 'pale_pink', 'bright_pink', 'normal_pink', he is more likely to live

# %%
query = '''
with cte as (
select outcome, sum(case when pain='severe_pain' then 1 else 0 end) as SeverePain,
            sum(case when pain='extreme_pain' then 1 else 0 end) as ExtremePain,
            (sum(case when pain='severe_pain' then 1 else 0 end) + sum(case when pain='extreme_pain' then 1 else 0 end)) as Total

        from data where pain is not null
group by 1)

select outcome, round(SeverePain*1.0/Total*100.0,2) as SeverePainPct , 
                round(ExtremePain*1.0/Total*100.0,2) as ExtremePainPct, 
        Total from cte
'''
temp = pd.read_sql(query, conn)
temp
# Out:
#       outcome  SeverePainPct  ExtremePainPct  Total
# 0        died          46.71           53.29    152
# 1  euthanized          74.29           25.71     70
# 2       lived          52.27           47.73     44

# %%
query = '''
with cte as (
select outcome, sum(case when pain='alert' then 1 else 0 end) as NoPain,
            sum(case when pain='depressed' then 1 else 0 end) as Depressed,
            sum(case when pain='mild_pain' then 1 else 0 end) as MildPain,
            sum(case when pain='slight' then 1 else 0 end) as SlightPain,
            (sum(case when pain='alert' then 1 else 0 end) + sum(case when pain='depressed' then 1 else 0 end) + 
            sum(case when pain='mild_pain' then 1 else 0 end) + sum(case when pain='slight' then 1 else 0 end)) as Total

        from data where pain is not null
group by 1)

select outcome, round(NoPain*1.0/Total*100.0,2) as NoPainPct , 
                round(Depressed*1.0/Total*100.0,2) as DepressedPct, 
                round(MildPain*1.0/Total*100.0,2) as MildPainPct,
                round(SlightPain*1.0/Total*100.0,2) as SlightPainPct,
        Total from cte
'''
temp2 = pd.read_sql(query, conn)
temp2
# Out:
#       outcome  NoPainPct  DepressedPct  MildPainPct  SlightPainPct  Total
# 0        died       0.40         69.17        30.43           0.00    253
# 1  euthanized       1.90         65.82        31.65           0.63    158
# 2       lived      16.15         29.18        54.67           0.00    514

# %% [markdown]
# **Does abdominal_distention have any impact on the outcome?**

# %%
query = '''
with cte as (select abdominal_distention,  
                sum(case when outcome = 'died' then 1 else 0 end) as died,       
                sum(case when outcome = 'euthanized' then 1 else 0 end) as euthanized,
                sum(case when outcome = 'lived' then 1 else 0 end) as lived,
                count(*) as total
from data 
where abdominal_distention is not null 
group by 1)

select abdominal_distention, (round(died*1.0/total*100,2) + 
                            round(euthanized*1.0/total*100,2)) as Died_pct, 
                            round(lived*1.0/total*100,2) as Lived_pct, total from cte
                            order by 3 desc
'''
distention = pd.read_sql(query, conn)
distention
# Out:
#   abdominal_distention  Died_pct  Lived_pct  total
# 0                 none     33.02      66.98    212
# 1               slight     39.60      60.40    346
# 2             moderate     63.35      36.65    543
# 3               severe     82.88      17.12    111

# %% [markdown]
# **INSIGHT**
#
# - With none or slight abdominal distention, the horse likely to live around 63% of the times.
# - With moderate or severe abdominal distention, the horse is most likely to die 72% of the times.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# **Fill Out the Null values**

# %%
null = pd.DataFrame(round(df.isnull().sum()/len(df)*100,2)).reset_index()\
            .rename(columns={'index': 'Column', 0:'Null_Pct'}).sort_values(by='Null_Pct', ascending=False).reset_index(drop=True)
null.query('Null_Pct!=0')
# Out:
#                    Column  Null_Pct
# 0                 abdomen     17.25
# 1       rectal_exam_feces     15.38
# 2        nasogastric_tube      6.48
# 3        peripheral_pulse      4.86
# 4       abdomo_appearance      3.89
# 5                    pain      3.56
# 6     temp_of_extremities      3.16
# 7    abdominal_distention      1.86
# 8      nasogastric_reflux      1.70
# 9         mucous_membrane      1.70
# 10            peristalsis      1.62
# 11  capillary_refill_time      0.49

# %%
#filling out the null values with the default value "Unknown"
null_cols = df[null.query('Null_Pct!=0')['Column']]
for col in null_cols:
    df[col].fillna('Unknown', inplace=True)

# %%
null_count = sum(list(df.isnull().sum().values.tolist()))
print(f"There are now {null_count} null values in the dataset after imputing.")
# Out:
# There are now 0 null values in the dataset after imputing.

# %% [markdown]
# **Label Encoding**

# %%
label_encoders = {}
mappings = {}

# Apply label encoding and store mappings
for column in cat_cols:
    if column in df.columns:
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column])
        label_encoders[column] = le
        # Create the mapping like you requested
        mappings[column] = dict(zip(le.transform(le.classes_), le.classes_))
print('Label Encoding Done and Mappings Saved for later use...')
# Out:
# Label Encoding Done and Mappings Saved for later use...

# %% [markdown]
# **Scaling**

# %%
num_cols = [i for i in num_cols if i not in ('id', 'hospital_number')]
df[num_cols]
# Out:
#       rectal_temp  pulse  respiratory_rate  nasogastric_reflux_ph  \
# 0            38.1  132.0              24.0                    6.5
# 1            37.5   88.0              12.0                    2.0
# 2            38.3  120.0              28.0                    3.5
# 3            37.1   72.0              30.0                    2.0
# 4            38.0   52.0              48.0                    7.0
# ...           ...    ...               ...                    ...
# 1230         38.5  129.0              48.0                    2.0
# 1231         37.5   60.0              50.0                    3.0
# 1232         37.5   84.0              40.0                    3.0
# 1233         38.1   70.0              16.0                    2.0
# 1234         38.1   54.0              36.0                    3.0
#
#       packed_cell_volume  total_protein  abdomo_protein  lesion_1  lesion_2  \
# 0                   57.0            8.5             3.4      2209         0
# ...

# %%
result_cols = []

for column in num_cols:
    result = anderson(df[column].dropna())
    # Check against critical values
    if result.statistic > result.critical_values[2]:  # Compare with 5% significance level
        result_cols.append(column)   
    else:
        print(f'{column} is normally distributed.')

print("Below are the cols that are not normally distributed")
result_cols
# Out:
# Below are the cols that are not normally distributed
# ['rectal_temp',
#  'pulse',
#  'respiratory_rate',
#  'nasogastric_reflux_ph',
#  'packed_cell_volume',
#  'total_protein',
#  'abdomo_protein',
#  'lesion_1',
#  'lesion_2',
#  'lesion_3']

# %%
cols = df.select_dtypes(exclude='object').columns.to_list()
scale_df = pd.DataFrame([ (i, df[i].min(), df[i].max()) for i in cols], columns=['Column', 'Min Value', 'Max Value'])
scale_df
# Out:
#                    Column  Min Value  Max Value
# 0                 surgery        0.0        1.0
# 1                     age        0.0        1.0
# 2         hospital_number   521399.0  5305129.0
# 3             rectal_temp       35.4       40.8
# 4                   pulse       30.0      184.0
# 5        respiratory_rate        8.0       96.0
# 6     temp_of_extremities        0.0        4.0
# 7        peripheral_pulse        0.0        4.0
# 8         mucous_membrane        0.0        6.0
# 9   capillary_refill_time        0.0        3.0
# 10                   pain        0.0        6.0
# 11            peristalsis        0.0        5.0
# 12   abdominal_distention        0.0        4.0
# 13       nasogastric_tube        0.0        3.0
# 14     nasogastric_reflux        0.0        4.0
# 15  nasogastric_reflux_ph        1.0        7.5
# 16      rectal_exam_feces        0.0        5.0
# 17                abdomen        0.0        5.0
# 18     packed_cell_volume       23.0       75.0
# ...

# %% [markdown]
# So, we see above is that the scale of different columns is way too difference so we will use 3 different scalers for the columns that need scaling. Let's go over these scalers that we will use
#
# | **Scaler**         | **Definition**                                                                 | **Difference**                                                                                                                                           |
# |--------------------|--------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **StandardScaler** | Standardizes features by removing the mean and scaling to unit variance.       | Best for normally distributed data, centering features around 0 with a standard deviation of 1.                                                           |
# | **MinMaxScaler**   | Scales features to a specified range, typically [0, 1].                        | Maintains relative relationships between data while transforming values to fit within a fixed range, suitable for algorithms sensitive to scale variations.|
# | **RobustScaler**   | Scales features using the median and interquartile range (IQR).                | Ideal for data with outliers as it uses median and IQR, making it less sensitive to extreme values.                                                        |

# %%
# Scaling continuous features with StandardScaler
standard_columns = ['rectal_temp', 'pulse', 'respiratory_rate', 'packed_cell_volume', 'total_protein', 'abdomo_protein']
scaler_standard = StandardScaler()
df[standard_columns] = scaler_standard.fit_transform(df[standard_columns])

# Scaling ordinal categorical features with MinMaxScaler
ordinal_columns = ['temp_of_extremities', 'peripheral_pulse', 'mucous_membrane', 'capillary_refill_time', 
                   'pain', 'peristalsis', 'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux',
                   'rectal_exam_feces', 'abdomen', 'abdomo_appearance', 'outcome']
scaler_minmax = MinMaxScaler()
df[ordinal_columns] = scaler_minmax.fit_transform(df[ordinal_columns])

# Scaling features with outliers using RobustScaler
robust_columns = ['nasogastric_reflux_ph', 'lesion_1', 'lesion_2', 'lesion_3']
scaler_robust = RobustScaler()
df[robust_columns] = scaler_robust.fit_transform(df[robust_columns])

# %% [markdown]
# Let's check the scale of the value (to cross verify if the scaling is done or not) after scaling them

# %%
scale_df = pd.DataFrame([ (i, round(df[i].min(),2), round(df[i].max(),2)) for i in cols],
                                 columns=['Column', 'Min Value', 'Max Value'])
scale_df
# Out:
#                    Column  Min Value   Max Value
# 0                 surgery       0.00        1.00
# 1                     age       0.00        1.00
# 2         hospital_number  521399.00  5305129.00
# 3             rectal_temp      -3.55        3.30
# 4                   pulse      -1.70        3.59
# 5        respiratory_rate      -1.34        4.01
# 6     temp_of_extremities       0.00        1.00
# 7        peripheral_pulse       0.00        1.00
# 8         mucous_membrane       0.00        1.00
# 9   capillary_refill_time       0.00        1.00
# 10                   pain       0.00        1.00
# 11            peristalsis       0.00        1.00
# 12   abdominal_distention       0.00        1.00
# 13       nasogastric_tube       0.00        1.00
# 14     nasogastric_reflux       0.00        1.00
# 15  nasogastric_reflux_ph      -0.88        0.75
# 16      rectal_exam_feces       0.00        1.00
# 17                abdomen       0.00        1.00
# ...

# %% [markdown]
# We don't need to scale Hospital Number since we won't be using the feature as it's just an identifier and won't impact the results.

# %% [markdown]
# **Feature Engineering**

# %%
cols = [i for i in df.columns if i not in ('id', 'hospital_number')]
data = df[cols].copy()
data.head()
# Out:
#    surgery  age  rectal_temp     pulse  respiratory_rate  temp_of_extremities  \
# 0        1    0    -0.129621  1.801773         -0.368142                 0.50
# 1        1    0    -0.890705  0.289582         -1.097830                 0.50
# 2        1    0     0.124074  1.389357         -0.124913                 0.50
# 3        1    0    -1.398095 -0.260306         -0.003299                 0.25
# 4        0    0    -0.256468 -0.947666          1.091232                 0.75
#
#    peripheral_pulse  mucous_membrane  capillary_refill_time      pain  \
# 0              1.00         0.500000               1.000000  0.333333
# 1              0.75         0.833333               1.000000  0.666667
# 2              1.00         1.000000               0.666667  0.500000
# 3              1.00         1.000000               1.000000  0.666667
# 4              0.75         0.666667               0.666667  0.166667
#
# ...

# %%
X_cols = [i for i in cols if i not in ('outcome')]
y_col =  'outcome'

# %%
X_train, X_test, y_train, y_test =  train_test_split(data[X_cols], data[y_col], test_size=0.25, random_state=42)

# %%
X_train.head()
# Out:
#       surgery  age  rectal_temp     pulse  respiratory_rate  \
# 793         0    0     0.124074 -0.810194          0.604774
# 670         0    0    -0.129621  1.114413         -0.368142
# 893         1    0    -0.510163  1.183149          0.361545
# 1108        1    0    -0.256468  0.633261          0.361545
# 39          1    0    -0.129621  2.076717          2.307377
#
#       temp_of_extremities  peripheral_pulse  mucous_membrane  \
# 793                  0.00               0.0         0.000000
# 670                  0.25               1.0         0.333333
# 893                  0.50               1.0         0.500000
# 1108                 0.50               1.0         0.833333
# 39                   0.50               1.0         0.166667
#
#       capillary_refill_time      pain  peristalsis  abdominal_distention  \
# 793                0.666667  0.000000          0.8                  0.00
# 670                1.000000  0.333333          0.2                  0.25
# ...

# %%
y_train.head()
# Out:
# 793     1.0
# 670     0.5
# 893     0.0
# 1108    1.0
# 39      0.5
# Name: outcome, dtype: float64

# %% [markdown]
# Training and evaluation

# %%
y_train_mapped = y_train.map({0.0: 0, 0.5: 1, 1.0: 2})
model = RandomForestClassifier(random_state=0)
model.fit(X_train.values, y_train_mapped.values)
# Out:
# RandomForestClassifier(random_state=0)

# %%
probs = model.predict_proba(X_train)
y_train_pred = np.argmax(probs,axis=1)
train_accuracy = accuracy_score(y_train_mapped, y_train_pred)
print(f"Train Accuracy: {train_accuracy:.2f}")
# Out:
# Train Accuracy: 1.00

# %%
probs = model.predict_proba(X_test)
y_pred = np.argmax(probs,axis=1)
y_test_mapped=  y_test.map({0.0: 0, 0.5: 1, 1.0: 2})
accuracy = accuracy_score(y_test_mapped, y_pred)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# Test Accuracy: 0.72

# %%
cross_val_scores = cross_val_score(model, X_train.values, y_train_mapped, cv=5)
print(f"Cross-Validation Scores: {cross_val_scores}")
print(f"Mean Cross-Validation Score: {cross_val_scores.mean():.2f}")
# Out:
# Cross-Validation Scores: [0.68817204 0.63243243 0.71891892 0.67567568 0.66486486]
# Mean Cross-Validation Score: 0.68

# %%
cross_val_test_scores = cross_val_score(model, X_test.values, y_test_mapped, cv=5)
print(f"Cross-Validation Test Scores: {cross_val_test_scores}")
print(f"Mean Cross-Validation  Test Score: {cross_val_test_scores.mean():.2f}")
# Out:
# Cross-Validation Test Scores: [0.75806452 0.64516129 0.59677419 0.74193548 0.70491803]
# Mean Cross-Validation  Test Score: 0.69

# %%
import seaborn as sns

# Assuming y_test contains the true labels and y_pred contains the predicted labels
conf_matrix = confusion_matrix(y_test_mapped, y_pred)

# Display the confusion matrix
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Generate the classification report
report = classification_report(y_test_mapped, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.70      0.65        90
#            1       0.87      0.64      0.74        73
#            2       0.75      0.77      0.76       146
#
#     accuracy                           0.72       309
#    macro avg       0.74      0.71      0.72       309
# weighted avg       0.74      0.72      0.72       309

# %% [markdown]
# When dealing with multi-class classification, where predictions involve more than just two categories, the standard ROC AUC metric requires a bit of adaptation. You can extend it effectively using two strategies: One-vs-Rest (OvR) and One-vs-One (OvO).
#
# In the **One-vs-Rest approach**, each class is treated individually as the "positive" class, while all other classes are grouped as the "negative" class. This method helps assess how well each class stands out from the rest. On the other hand, the **One-vs-One approach** involves comparing every pair of classes in a series of "duels," providing a detailed view of how well the model differentiates between each possible class pair.
#
# Understanding these strategies and the `multi_class` parameter—where `'ovr'` evaluates each class against the combined opposition and `'ovo'` compares every pair—allows you to adapt the ROC AUC metric to the complexities of multi-class classification, offering a clear and nuanced view of your model's performance.

# %%
# Binarize the output (necessary for multi-class)
y_test_binarized = label_binarize(y_test_mapped, classes=[0, 1, 2])  # Adjust classes as needed
y_pred_proba = model.predict_proba(X_test.values)

# Calculate ROC AUC using the OvR approach
roc_auc_ovr = roc_auc_score(y_test_binarized, y_pred_proba, multi_class='ovr')
print(f"ROC AUC Score (OvR): {roc_auc_ovr:.2f}")

# Alternatively, use the OvO approach
roc_auc_ovo = roc_auc_score(y_test_binarized, y_pred_proba, multi_class='ovo')
print(f"ROC AUC Score (OvO): {roc_auc_ovo:.2f}")
# Out:
# ROC AUC Score (OvR): 0.86
# ROC AUC Score (OvO): 0.86

# %% [markdown]
# **Tuning the model**

# %%
# Define the model
model = RandomForestClassifier(random_state=0)

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'bootstrap': [True, False]
}

# Set up the GridSearchCV
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                           cv=5, scoring='accuracy', n_jobs=-1, verbose=0)

# Fit GridSearchCV
grid_search.fit(X_train, y_train_mapped)

# Print the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Best Score: 0.6943679163034002

# %% [markdown]
# FItting the new model

# %%
new_model = grid_search.best_estimator_
new_model.fit(X_train.values, y_train_mapped.values)
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=200, random_state=0)

# %%
probs = new_model.predict_proba(X_test)
y_pred = np.argmax(probs,axis=1)
accuracy = accuracy_score(y_test_mapped, y_pred)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# Test Accuracy: 0.72

# %% [markdown]
# Test Accuracy Remains the same
